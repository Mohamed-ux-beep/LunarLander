# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamed-ux-beep/LunarLander/blob/main/Reinforcement_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Huggingface Reinforcement learning course tasks -- my first agent creation and training
# Downloading all dependencies
# Script with all what we need which is * Gymnasium environment library * Stable-Baselines3

# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.1).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 0s (2,536 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121654 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt

# %%
# virtual screen library to render the environment and thus record the frames
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# to make sure the new intalled libraries are used, it is important to restart the notebook runtime
import os
os.kill(os.getpid(), 9)

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# One additional library we import is huggingface_hub to be able to upload and download trained models from the hub.
import gymnasium
from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %% [markdown]
# 🏋 The library containing our environment is called Gymnasium. You'll use Gymnasium a lot in Deep Reinforcement Learning.
#
# Gymnasium is the new version of Gym library maintained by the Farama Foundation.
#
# The Gymnasium library provides two things:
#
# An interface that allows you to create RL environments.
# A collection of environments (gym-control, atari, box2D...).

# %%
import gymnasium as gym

# first we create our environment called LunarLander-v2
env = gym.make('LunarLander-v2')

# then we reset this environment
observation, info = env.reset()

for _ in range(20):
  # make a random action
  action = env.action_space.sample()
  print('Action taken: ', action)

# do this action in the environment and get next state, reward, terminated, truncated and info
observation, reward, terminated, truncated, info = env.step(action)

# if the game is terminated (in our case we land, or crashed) or truncated (timed out)
if terminated or truncated:
  print('Environment is reset')
  observation, info = env.reset()

# close the environment
env.close()
# Out:
# Action taken:  3
# Action taken:  0
# Action taken:  3
# Action taken:  3
# Action taken:  3
# Action taken:  0
# Action taken:  2
# Action taken:  1
# Action taken:  0
# Action taken:  1
# Action taken:  0
# Action taken:  2
# Action taken:  3
# Action taken:  1
# Action taken:  3
# Action taken:  1
# Action taken:  1
# Action taken:  2
# Action taken:  2
# Action taken:  0

# %%
# our agent is Lunar we need to train it to adapt its speed and position (horizontal, vertical and angular) in order to land correctly on the moon
env = gym.make('LunarLander-v2')
print("__ OBSERVATION SPACE __ \n")
print("observation space shape ", env.observation_space.shape)
print("Sample observation ", env.observation_space.sample())
# Out:
# __ OBSERVATION SPACE __
#
# observation space shape  (8,)
# Sample observation  [4.2832294e+01 7.9984886e+01 1.2503858e+00 4.8145494e+00 1.8510625e+00
#  2.9413311e+00 1.3339916e-01 5.8134116e-02]

# %%
# observation space shape 8, :
# 1: (x, y) coordinate                         -- 2
# 2: (x, y) velocity                           -- 2
# 3: angle angular                             -- 1
# 4: velocity                                  -- 1
# 5: left leg in contact with land? Boolean    -- 1
# 6: right leg in contact with land? Boolean   -- 1
# Total ------------------------------------> (2+2+1+1+1+1) = 8 dimensions

# %%
print("__ ACTION SPACE __ \n")
print("action space shape ", env.action_space.n)
print("action space sample ", env.action_space.sample())
# Out:
# __ ACTION SPACE __
#
# action space shape  4
# action space sample  2

# %%
# action space
# 0: Do nothing
# 1: fire left orientation engine
# 2: fire main engine
# 3: fire right orientation engine

# %% [markdown]
# **Vectorized environment**
#
# we will use vectorized environment in order to stack 16 environment together in one environment to have more experience in training

# %%
env = make_vec_env('LunarLander-v2', n_envs=16)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **We will be using PPO Proximal policy optimization Algorithm. it is state of art algorithm used in Deep Reinforcement Learning**

# %%
# stable baseline3 is easy to setup :
# 1. you create an environment
# 2. you define the model
# 3. you train the agent with model.learn()

# %%
# MlpPolicy --> multilayer perceptron

# %%
# create an Environment
env = gym.make('LunarLander-v2')

# Instantiate the agent
model = PPO('MlpPolicy', env, verbose=1)

# Train the agent
model.learn(total_timesteps= int(2e5))
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.7     |
# |    ep_rew_mean     | -186     |
# | time/              |          |
# |    fps             | 456      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.3         |
# |    ep_rew_mean          | -199         |
# | time/                   |              |
# |    fps                  | 435          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0069944286 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00305     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 858          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00805     |
# |    value_loss           | 1.76e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.3        |
# |    ep_rew_mean          | -189        |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008885715 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0288     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 977         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00798    |
# |    value_loss           | 1.78e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.7        |
# |    ep_rew_mean          | -175        |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007162674 |
# |    clip_fraction        | 0.0263      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00535    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 655         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00804    |
# |    value_loss           | 982         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017110953 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00561    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 311         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 581         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -159        |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 6           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008750609 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0167      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 197         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 500         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 114         |
# |    ep_rew_mean          | -146        |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 7           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012562205 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.0141     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 229         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 532         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -129        |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 8           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007526896 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.00141    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 128         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 313         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 9           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013488295 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.00026    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 154         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 289         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 10          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009516814 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.0047     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 317         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00805    |
# |    value_loss           | 501         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 11          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011045732 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.000331    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 285         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 12          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006040082 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.00235     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 171         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 238         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | -95.3       |
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 13          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007709318 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.014       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 264         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 430         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 173          |
# |    ep_rew_mean          | -87.2        |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 14           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0075469958 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.00945      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 121          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 303          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 180        |
# |    ep_rew_mean          | -83.1      |
# | time/                   |            |
# |    fps                  | 461        |
# |    iterations           | 15         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00425554 |
# |    clip_fraction        | 0.00708    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.156      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 83.2       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00298   |
# |    value_loss           | 206        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 16          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010807971 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0204     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0095     |
# |    value_loss           | 390         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | -74.8       |
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 17          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004284928 |
# |    clip_fraction        | 0.0102      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.0759     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 345         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 212          |
# |    ep_rew_mean          | -70.9        |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 18           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0049659307 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 188          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | -70.1        |
# | time/                   |              |
# |    fps                  | 465          |
# |    iterations           | 19           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0068370462 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.7         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 273          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | -66.2       |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 20          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004830993 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 194         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | -65.7       |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 21          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006016623 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 128         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00516    |
# |    value_loss           | 308         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 260          |
# |    ep_rew_mean          | -66.6        |
# | time/                   |              |
# |    fps                  | 465          |
# |    iterations           | 22           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0024298716 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56.3         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 169          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | -69.7       |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 23          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004373096 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.3        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 203         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | -71.7        |
# | time/                   |              |
# |    fps                  | 465          |
# |    iterations           | 24           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0073321545 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.8         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00936     |
# |    value_loss           | 205          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | -70.8       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 25          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013093094 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.6        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00969    |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 313         |
# |    ep_rew_mean          | -71.5       |
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 26          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009070939 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.4        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0078     |
# |    value_loss           | 65.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 324         |
# |    ep_rew_mean          | -72         |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 27          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010785803 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 90.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | -74.5       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 28          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007983493 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | -72.3       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 29          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013982351 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 77.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 367         |
# |    ep_rew_mean          | -73.5       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 30          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011455206 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00797    |
# |    value_loss           | 75.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 376         |
# |    ep_rew_mean          | -71.4       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 31          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.016167594 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 58.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 393         |
# |    ep_rew_mean          | -68.3       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 32          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009959258 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.02        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00623    |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 409         |
# |    ep_rew_mean          | -66.7       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 33          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008960983 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00747    |
# |    value_loss           | 53.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 426         |
# |    ep_rew_mean          | -66.1       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 34          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012385314 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.62        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 9.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 443         |
# |    ep_rew_mean          | -64.1       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 35          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011073822 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.45        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00907    |
# |    value_loss           | 7.06        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 448          |
# |    ep_rew_mean          | -64.8        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 36           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0018861296 |
# |    clip_fraction        | 0.00571      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.6         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 83.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 468         |
# |    ep_rew_mean          | -60.9       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 37          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004132405 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00218    |
# |    value_loss           | 63          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 484         |
# |    ep_rew_mean          | -57.8       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 38          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007879246 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.6         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 47.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -55.1        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 39           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0135183055 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.5          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00707     |
# |    value_loss           | 6.02         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 514         |
# |    ep_rew_mean          | -49.8       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 40          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010788103 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.94       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.66        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00545    |
# |    value_loss           | 8.04        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 527          |
# |    ep_rew_mean          | -44.2        |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 41           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0044154376 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.954       |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.8         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00435     |
# |    value_loss           | 78.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 545          |
# |    ep_rew_mean          | -42.3        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 42           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0051986994 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.539        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.1          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 69.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 557         |
# |    ep_rew_mean          | -37.8       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 43          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.012131892 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.92        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 47.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 570         |
# |    ep_rew_mean          | -35         |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 44          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011450048 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.68        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 24.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 586          |
# |    ep_rew_mean          | -30.4        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 45           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0068202564 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.906       |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.81         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00505     |
# |    value_loss           | 91.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 606        |
# |    ep_rew_mean          | -25.9      |
# | time/                   |            |
# |    fps                  | 466        |
# |    iterations           | 46         |
# |    time_elapsed         | 201        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01359702 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.79       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00439   |
# |    value_loss           | 7.62       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 621         |
# |    ep_rew_mean          | -22.6       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 47          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010465244 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.34        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 21.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 629         |
# |    ep_rew_mean          | -21.8       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 48          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012176179 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 5.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 635         |
# |    ep_rew_mean          | -20.3       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 49          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007892356 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.7        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 68.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 650         |
# |    ep_rew_mean          | -16.1       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 50          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006342028 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.982      |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 79.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 666         |
# |    ep_rew_mean          | -13.7       |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 51          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007618777 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.65        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 685          |
# |    ep_rew_mean          | -7.94        |
# | time/                   |              |
# |    fps                  | 467          |
# |    iterations           | 52           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0082010515 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.57         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00843     |
# |    value_loss           | 4.47         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 694         |
# |    ep_rew_mean          | -6.06       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 53          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008688526 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 4.99        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 709          |
# |    ep_rew_mean          | -2.73        |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 54           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0046954965 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.896       |
# |    explained_variance   | 0.572        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.5         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 41.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 724        |
# |    ep_rew_mean          | 1.51       |
# | time/                   |            |
# |    fps                  | 467        |
# |    iterations           | 55         |
# |    time_elapsed         | 240        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.00973063 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.885     |
# ...
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 515         |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 81          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.013402992 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00499    |
# |    value_loss           | 113         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 515          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 82           |
# |    time_elapsed         | 358          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0072812396 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.809       |
# |    explained_variance   | 0.721        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.1         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 59.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 514         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 83          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.004126312 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.6        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -3.15e-05   |
# |    value_loss           | 64.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 522         |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 84          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.003432882 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00197    |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 512         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 85          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.004591395 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 61.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 507         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 86          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.005189983 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.801      |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00196    |
# |    value_loss           | 57.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | 114         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 87          |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.006966028 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.801      |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 132         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 484        |
# |    ep_rew_mean          | 116        |
# | time/                   |            |
# |    fps                  | 468        |
# |    iterations           | 88         |
# |    time_elapsed         | 384        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.00776926 |
# |    clip_fraction        | 0.0589     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.841     |
# |    explained_variance   | 0.692      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 112        |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.00536   |
# |    value_loss           | 167        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 471          |
# |    ep_rew_mean          | 120          |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 89           |
# |    time_elapsed         | 389          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0062028375 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.712        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31           |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 175          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 465          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 90           |
# |    time_elapsed         | 393          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0046456447 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 0.625        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47           |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 156          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 464         |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 91          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.004667412 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.000977   |
# |    value_loss           | 60.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 92           |
# |    time_elapsed         | 402          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0029315373 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.641       |
# |    explained_variance   | 0.756        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.2         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 109          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 130          |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 93           |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0038529793 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.638       |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.4         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 49.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 457          |
# |    ep_rew_mean          | 132          |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 94           |
# |    time_elapsed         | 410          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0071547735 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.703       |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.9         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.000909    |
# |    value_loss           | 149          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 95          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.007383376 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.766      |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.48        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 459         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 96          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.018705066 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 448         |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 97          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.014727071 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.777      |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.3        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00401    |
# |    value_loss           | 129         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 443         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 98          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.005933517 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.679      |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.9        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 136         |
# -----------------------------------------

# %%
model.learn(total_timesteps=1000000)
model_name = 'ppo-LunarLander-v2'
model.save(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# |    value_loss           | 180          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 309         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 252         |
# |    time_elapsed         | 1082        |
# |    total_timesteps      | 516096      |
# | train/                  |             |
# |    approx_kl            | 0.005059529 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48          |
# |    n_updates            | 3490        |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 115         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 253          |
# |    time_elapsed         | 1086         |
# |    total_timesteps      | 518144       |
# | train/                  |              |
# |    approx_kl            | 0.0034927614 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.5         |
# |    n_updates            | 3500         |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 132          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | 193          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 254          |
# |    time_elapsed         | 1091         |
# |    total_timesteps      | 520192       |
# | train/                  |              |
# |    approx_kl            | 0.0031345952 |
# |    clip_fraction        | 0.0587       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.551       |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.6         |
# |    n_updates            | 3510         |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 140          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 255          |
# |    time_elapsed         | 1095         |
# |    total_timesteps      | 522240       |
# | train/                  |              |
# |    approx_kl            | 0.0030624284 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.538       |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.29         |
# |    n_updates            | 3520         |
# |    policy_gradient_loss | -0.000257    |
# |    value_loss           | 78.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 312          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 256          |
# |    time_elapsed         | 1099         |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0104261115 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.777        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.97         |
# |    n_updates            | 3530         |
# |    policy_gradient_loss | -0.00436     |
# |    value_loss           | 39.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 257         |
# |    time_elapsed         | 1103        |
# |    total_timesteps      | 526336      |
# | train/                  |             |
# |    approx_kl            | 0.008002426 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 3540        |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 40.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 324        |
# |    ep_rew_mean          | 193        |
# | time/                   |            |
# |    fps                  | 476        |
# |    iterations           | 258        |
# |    time_elapsed         | 1108       |
# |    total_timesteps      | 528384     |
# | train/                  |            |
# |    approx_kl            | 0.01080825 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.62      |
# |    explained_variance   | 0.8        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.587      |
# |    n_updates            | 3550       |
# |    policy_gradient_loss | 0.00143    |
# |    value_loss           | 18.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 318          |
# |    ep_rew_mean          | 194          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 259          |
# |    time_elapsed         | 1112         |
# |    total_timesteps      | 530432       |
# | train/                  |              |
# |    approx_kl            | 0.0096592065 |
# |    clip_fraction        | 0.165        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.5          |
# |    n_updates            | 3560         |
# |    policy_gradient_loss | -0.00376     |
# |    value_loss           | 37.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | 188         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 260         |
# |    time_elapsed         | 1116        |
# |    total_timesteps      | 532480      |
# | train/                  |             |
# |    approx_kl            | 0.004705697 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19        |
# |    n_updates            | 3570        |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 110         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | 193          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 261          |
# |    time_elapsed         | 1121         |
# |    total_timesteps      | 534528       |
# | train/                  |              |
# |    approx_kl            | 0.0050726323 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0.757        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.9         |
# |    n_updates            | 3580         |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | 197         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 262         |
# |    time_elapsed         | 1125        |
# |    total_timesteps      | 536576      |
# | train/                  |             |
# |    approx_kl            | 0.010466691 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.42        |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 14.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 343         |
# |    ep_rew_mean          | 199         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 263         |
# |    time_elapsed         | 1129        |
# |    total_timesteps      | 538624      |
# | train/                  |             |
# |    approx_kl            | 0.013872777 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.17        |
# |    n_updates            | 3600        |
# |    policy_gradient_loss | -0.000424   |
# |    value_loss           | 11          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 201          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 264          |
# |    time_elapsed         | 1134         |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0071689086 |
# |    clip_fraction        | 0.0776       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.78         |
# |    n_updates            | 3610         |
# |    policy_gradient_loss | -0.000467    |
# |    value_loss           | 63.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 347          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 265          |
# |    time_elapsed         | 1138         |
# |    total_timesteps      | 542720       |
# | train/                  |              |
# |    approx_kl            | 0.0032298262 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.718        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.9         |
# |    n_updates            | 3620         |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 67.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 338          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 266          |
# |    time_elapsed         | 1142         |
# |    total_timesteps      | 544768       |
# | train/                  |              |
# |    approx_kl            | 0.0030142923 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.4         |
# |    n_updates            | 3630         |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 66.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 339          |
# |    ep_rew_mean          | 197          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 267          |
# |    time_elapsed         | 1147         |
# |    total_timesteps      | 546816       |
# | train/                  |              |
# |    approx_kl            | 0.0039348756 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.5         |
# |    n_updates            | 3640         |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 129          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 345         |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 268         |
# |    time_elapsed         | 1151        |
# |    total_timesteps      | 548864      |
# | train/                  |             |
# |    approx_kl            | 0.007811063 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.94        |
# |    n_updates            | 3650        |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 20.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 346         |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 269         |
# |    time_elapsed         | 1155        |
# |    total_timesteps      | 550912      |
# | train/                  |             |
# |    approx_kl            | 0.012325495 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.36        |
# |    n_updates            | 3660        |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 89.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 355          |
# |    ep_rew_mean          | 201          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 270          |
# |    time_elapsed         | 1159         |
# |    total_timesteps      | 552960       |
# | train/                  |              |
# |    approx_kl            | 0.0038657812 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.1         |
# |    n_updates            | 3670         |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 197          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 271          |
# |    time_elapsed         | 1163         |
# |    total_timesteps      | 555008       |
# | train/                  |              |
# |    approx_kl            | 0.0042504496 |
# |    clip_fraction        | 0.0843       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.6         |
# |    n_updates            | 3680         |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 58.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 363          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 272          |
# |    time_elapsed         | 1168         |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0040318468 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.638       |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.1         |
# |    n_updates            | 3690         |
# |    policy_gradient_loss | -0.00072     |
# |    value_loss           | 126          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 196          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 273          |
# |    time_elapsed         | 1172         |
# |    total_timesteps      | 559104       |
# | train/                  |              |
# |    approx_kl            | 0.0069518844 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.842        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25         |
# |    n_updates            | 3700         |
# |    policy_gradient_loss | -4.22e-05    |
# |    value_loss           | 46.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 368         |
# |    ep_rew_mean          | 195         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 274         |
# |    time_elapsed         | 1177        |
# |    total_timesteps      | 561152      |
# | train/                  |             |
# |    approx_kl            | 0.010967204 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.19        |
# |    n_updates            | 3710        |
# |    policy_gradient_loss | -0.000262   |
# |    value_loss           | 28.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 345         |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 275         |
# |    time_elapsed         | 1181        |
# |    total_timesteps      | 563200      |
# | train/                  |             |
# |    approx_kl            | 0.012640774 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.432      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.9        |
# |    n_updates            | 3720        |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 76.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 355          |
# |    ep_rew_mean          | 195          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 276          |
# |    time_elapsed         | 1185         |
# |    total_timesteps      | 565248       |
# | train/                  |              |
# |    approx_kl            | 0.0071065575 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.82         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 108          |
# |    n_updates            | 3730         |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 148          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 349          |
# |    ep_rew_mean          | 201          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 277          |
# |    time_elapsed         | 1190         |
# |    total_timesteps      | 567296       |
# | train/                  |              |
# |    approx_kl            | 0.0019404698 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.75         |
# |    n_updates            | 3740         |
# |    policy_gradient_loss | 0.000184     |
# |    value_loss           | 50.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 361          |
# |    ep_rew_mean          | 197          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 278          |
# |    time_elapsed         | 1194         |
# |    total_timesteps      | 569344       |
# | train/                  |              |
# |    approx_kl            | 0.0053966893 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.26         |
# |    n_updates            | 3750         |
# |    policy_gradient_loss | 0.00212      |
# |    value_loss           | 24.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | 199         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 279         |
# |    time_elapsed         | 1198        |
# |    total_timesteps      | 571392      |
# | train/                  |             |
# |    approx_kl            | 0.005014466 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.4        |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.1        |
# |    n_updates            | 3760        |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 72          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 338         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 280         |
# |    time_elapsed         | 1203        |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.008099789 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.41        |
# |    n_updates            | 3770        |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 20          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | 201          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 281          |
# |    time_elapsed         | 1207         |
# |    total_timesteps      | 575488       |
# | train/                  |              |
# |    approx_kl            | 0.0034620631 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | 0.415        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 145          |
# |    n_updates            | 3780         |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 127          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 201        |
# | time/                   |            |
# |    fps                  | 476        |
# |    iterations           | 282        |
# |    time_elapsed         | 1211       |
# |    total_timesteps      | 577536     |
# | train/                  |            |
# |    approx_kl            | 0.00468125 |
# |    clip_fraction        | 0.0443     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.467     |
# |    explained_variance   | 0.547      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 289        |
# |    n_updates            | 3790       |
# |    policy_gradient_loss | -0.000543  |
# |    value_loss           | 126        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 199          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 283          |
# |    time_elapsed         | 1215         |
# |    total_timesteps      | 579584       |
# | train/                  |              |
# |    approx_kl            | 0.0038273619 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.6         |
# |    n_updates            | 3800         |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 115          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 329         |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 284         |
# |    time_elapsed         | 1219        |
# |    total_timesteps      | 581632      |
# | train/                  |             |
# |    approx_kl            | 0.001933538 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.9        |
# |    n_updates            | 3810        |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 133         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 285         |
# |    time_elapsed         | 1224        |
# |    total_timesteps      | 583680      |
# | train/                  |             |
# |    approx_kl            | 0.013431918 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.51        |
# |    n_updates            | 3820        |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 53          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 327          |
# |    ep_rew_mean          | 208          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 286          |
# |    time_elapsed         | 1228         |
# |    total_timesteps      | 585728       |
# | train/                  |              |
# |    approx_kl            | 0.0058826255 |
# |    clip_fraction        | 0.088        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.508       |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.9          |
# |    n_updates            | 3830         |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 15.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 287         |
# |    time_elapsed         | 1232        |
# |    total_timesteps      | 587776      |
# | train/                  |             |
# |    approx_kl            | 0.004807296 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 3840        |
# |    policy_gradient_loss | -0.000755   |
# |    value_loss           | 68.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 288         |
# |    time_elapsed         | 1237        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.006084076 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.5        |
# |    n_updates            | 3850        |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 85.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 312          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 289          |
# |    time_elapsed         | 1241         |
# |    total_timesteps      | 591872       |
# | train/                  |              |
# |    approx_kl            | 0.0053013996 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32           |
# |    n_updates            | 3860         |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 311          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 290          |
# |    time_elapsed         | 1245         |
# |    total_timesteps      | 593920       |
# | train/                  |              |
# |    approx_kl            | 0.0060830866 |
# |    clip_fraction        | 0.0689       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.532       |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 3870         |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 64.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | 222         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 291         |
# |    time_elapsed         | 1250        |
# |    total_timesteps      | 595968      |
# | train/                  |             |
# |    approx_kl            | 0.009101485 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 3880        |
# |    policy_gradient_loss | -0.00134    |
# |    value_loss           | 65          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 301         |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 292         |
# |    time_elapsed         | 1254        |
# |    total_timesteps      | 598016      |
# | train/                  |             |
# |    approx_kl            | 0.004938416 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.58        |
# |    n_updates            | 3890        |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 39.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 293         |
# |    time_elapsed         | 1258        |
# |    total_timesteps      | 600064      |
# | train/                  |             |
# |    approx_kl            | 0.009634651 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.19        |
# |    n_updates            | 3900        |
# |    policy_gradient_loss | -0.00184    |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 294         |
# |    time_elapsed         | 1263        |
# |    total_timesteps      | 602112      |
# | train/                  |             |
# |    approx_kl            | 0.019731227 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.2        |
# |    n_updates            | 3910        |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 59.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 310          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 295          |
# |    time_elapsed         | 1267         |
# |    total_timesteps      | 604160       |
# | train/                  |              |
# |    approx_kl            | 0.0058414233 |
# |    clip_fraction        | 0.0606       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.83         |
# |    n_updates            | 3920         |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 21.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 296         |
# |    time_elapsed         | 1271        |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.005163543 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 3930        |
# |    policy_gradient_loss | 6.14e-06    |
# |    value_loss           | 57.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 321          |
# |    ep_rew_mean          | 219          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 297          |
# |    time_elapsed         | 1275         |
# |    total_timesteps      | 608256       |
# | train/                  |              |
# |    approx_kl            | 0.0036946984 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.441       |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.06         |
# |    n_updates            | 3940         |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 22.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 298         |
# |    time_elapsed         | 1280        |
# |    total_timesteps      | 610304      |
# | train/                  |             |
# |    approx_kl            | 0.007366838 |
# |    clip_fraction        | 0.0709      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.35        |
# |    n_updates            | 3950        |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 11.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 352         |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 299         |
# |    time_elapsed         | 1284        |
# |    total_timesteps      | 612352      |
# | train/                  |             |
# |    approx_kl            | 0.008121535 |
# |    clip_fraction        | 0.0694      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.307       |
# |    n_updates            | 3960        |
# |    policy_gradient_loss | 0.00134     |
# |    value_loss           | 4.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 352         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 300         |
# |    time_elapsed         | 1288        |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.012408704 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.5        |
# |    n_updates            | 3970        |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 39.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 359          |
# |    ep_rew_mean          | 223          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 301          |
# |    time_elapsed         | 1292         |
# |    total_timesteps      | 616448       |
# | train/                  |              |
# |    approx_kl            | 0.0011967928 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.678        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.9         |
# |    n_updates            | 3980         |
# |    policy_gradient_loss | -0.000337    |
# |    value_loss           | 124          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 222          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 302          |
# |    time_elapsed         | 1297         |
# |    total_timesteps      | 618496       |
# | train/                  |              |
# |    approx_kl            | 0.0040468657 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.8         |
# |    n_updates            | 3990         |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 34.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 360         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 303         |
# |    time_elapsed         | 1301        |
# |    total_timesteps      | 620544      |
# | train/                  |             |
# |    approx_kl            | 0.007816718 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.02        |
# |    n_updates            | 4000        |
# |    policy_gradient_loss | -0.00525    |
# |    value_loss           | 18.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 304          |
# |    time_elapsed         | 1305         |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0064832442 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.589       |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.81         |
# |    n_updates            | 4010         |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 61           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 374         |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# ...
# |    ep_len_mean          | 328          |
# |    ep_rew_mean          | 216          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 472          |
# |    time_elapsed         | 2027         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0034258817 |
# |    clip_fraction        | 0.0775       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.337       |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.35         |
# |    n_updates            | 5690         |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 24.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 473         |
# |    time_elapsed         | 2031        |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.013240885 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.49        |
# |    n_updates            | 5700        |
# |    policy_gradient_loss | 0.00113     |
# |    value_loss           | 87.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 340         |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 474         |
# |    time_elapsed         | 2036        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.007823946 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.431      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.81        |
# |    n_updates            | 5710        |
# |    policy_gradient_loss | -0.000752   |
# |    value_loss           | 10.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 333          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 475          |
# |    time_elapsed         | 2040         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0036082005 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.322       |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 131          |
# |    n_updates            | 5720         |
# |    policy_gradient_loss | -0.000308    |
# |    value_loss           | 66           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 476          |
# |    time_elapsed         | 2044         |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0080611715 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.312       |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.65         |
# |    n_updates            | 5730         |
# |    policy_gradient_loss | -0.000952    |
# |    value_loss           | 15.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 477          |
# |    time_elapsed         | 2049         |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0078670215 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.415       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.12         |
# |    n_updates            | 5740         |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 9.49         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 478         |
# |    time_elapsed         | 2053        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.009165404 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.429      |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.7        |
# |    n_updates            | 5750        |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 93.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 338          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 479          |
# |    time_elapsed         | 2057         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0034629782 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.416       |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.6         |
# |    n_updates            | 5760         |
# |    policy_gradient_loss | 0.000483     |
# |    value_loss           | 55.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 480         |
# |    time_elapsed         | 2062        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.003823958 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.444      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.45        |
# |    n_updates            | 5770        |
# |    policy_gradient_loss | -0.000231   |
# |    value_loss           | 15.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 481         |
# |    time_elapsed         | 2066        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.016458249 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.79        |
# |    n_updates            | 5780        |
# |    policy_gradient_loss | -0.000741   |
# |    value_loss           | 21.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 316         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 482         |
# |    time_elapsed         | 2070        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.003945594 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.325      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.61        |
# |    n_updates            | 5790        |
# |    policy_gradient_loss | 0.00114     |
# |    value_loss           | 14          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 483          |
# |    time_elapsed         | 2074         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0037278633 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.4          |
# |    n_updates            | 5800         |
# |    policy_gradient_loss | -0.000349    |
# |    value_loss           | 27           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 325         |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 484         |
# |    time_elapsed         | 2078        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.004734788 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.46        |
# |    n_updates            | 5810        |
# |    policy_gradient_loss | -0.00072    |
# |    value_loss           | 13.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 485          |
# |    time_elapsed         | 2083         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0057967557 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.59         |
# |    n_updates            | 5820         |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 20.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 486          |
# |    time_elapsed         | 2087         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0028761097 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.323       |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.8         |
# |    n_updates            | 5830         |
# |    policy_gradient_loss | -0.000795    |
# |    value_loss           | 99.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 487         |
# |    time_elapsed         | 2091        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.007628008 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.307      |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 5840        |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 123         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 235          |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 488          |
# |    time_elapsed         | 2096         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0056629702 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.295       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.98         |
# |    n_updates            | 5850         |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 23           |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 320        |
# |    ep_rew_mean          | 230        |
# | time/                   |            |
# |    fps                  | 476        |
# |    iterations           | 489        |
# |    time_elapsed         | 2100       |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.01209959 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.431     |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.66       |
# |    n_updates            | 5860       |
# |    policy_gradient_loss | -0.00278   |
# |    value_loss           | 20.8       |
# ----------------------------------------

# %%
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# mean_reward=251.91 +/- 69.73277229144914

# %%
# it is more than 200, so our luna is ready to land on the moon
# pushing my trained model on the hub
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

# PLACE the variables you've just defined two cells above
# Define the name of the environment
env_id = "LunarLander-v2"

# TODO: Define the model architecture we used
model_architecture = "PPO"

## Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
## CHANGE WITH YOUR REPO ID
repo_id = "Mohamedabokahf/LunarLander" # Change with your repo id, you can't push with mine 😄

## Define the commit message
commit_message = "Upload PPO LunarLander-v2 trained agent"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

# PLACE the package_to_hub function you've just filled here
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmpznnwkf7p/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpznnwkf7p/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpznnwkf7p/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpznnwkf7p/-step-0-to-step-1000.mp4
# ℹ Pushing repo Mohamedabokahf/LunarLander to the Hugging Face Hub
# policy.optimizer.pth:   0%|          | 0.00/88.4k [00:00<?, ?B/s]
# policy.pth:   0%|          | 0.00/43.8k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# ppo-LunarLander-v2.zip:   0%|          | 0.00/147k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Mohamedabokahf/LunarLander/tree/main/
# CommitInfo(commit_url='https://huggingface.co/Mohamedabokahf/LunarLander/commit/7e5fccc9402096cdd1106e7e17b8c1011ec80841', commit_message='Upload PPO LunarLander-v2 trained agent', commit_description='', oid='7e5fccc9402096cdd1106e7e17b8c1011ec80841', pr_url=None, pr_revision=None, pr_num=None)

# %%
# loading my model
# !pip install shimmy

# %%
from huggingface_sb3 import load_from_hub
repo_id = "Mohamedabokahf/LunarLander"
filename = 'ppo-LunarLander-v2.zip'
custom_objects = {
     "learning_rate": 0.0,
     "lr_schedule": lambda _: 0.0,
     "clip_range": lambda _: 0.0,
}
checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ppo-LunarLander-v2.zip:   0%|          | 0.00/147k [00:00<?, ?B/s]
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.1.58+-x86_64-with-glibc2.35 # 1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# - Python: 3.10.12
# - Stable-Baselines3: 2.0.0a5
# - PyTorch: 2.1.0+cu121
# - GPU Enabled: True
# - Numpy: 1.23.5
# - Cloudpickle: 2.2.1
# - Gymnasium: 0.28.1
# - OpenAI Gym: 0.25.2
#
# == SAVED MODEL SYSTEM INFO ==
# - OS: Linux-6.1.58+-x86_64-with-glibc2.35 # 1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# - Python: 3.10.12
# - Stable-Baselines3: 2.0.0a5
# - PyTorch: 2.1.0+cu121
# - GPU Enabled: True
# - Numpy: 1.23.5
# - Cloudpickle: 2.2.1
# - Gymnasium: 0.28.1
# - OpenAI Gym: 0.25.2

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=269.14 +/- 16.560008768458562
